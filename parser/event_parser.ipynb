# %%
from sqlalchemy import create_engine, text
import os
from dotenv import load_dotenv

engine = create_engine(f'postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@localhost:5432/f1pace')

# %%
from fastf1 import get_event_schedule
import pandas as pd

events_schedule_df = pd.DataFrame()
for year in range(2018, 2027):

    response_frame = get_event_schedule(year)
    response_frame['year'] = year

    events_schedule_df = pd.concat([events_schedule_df, response_frame])
    
events_schedule_df
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (11.08 GB) /home/user/.cache/fastf1
#     RoundNumber               Country     Location  \
# 0             1             Australia    Melbourne
# 1             2               Bahrain       Sakhir
# 2             3                 China     Shanghai
# 3             4            Azerbaijan         Baku
# 4             5                 Spain    Barcelona
# ..          ...                   ...          ...
# 19           18                Mexico  Mexico City
# 20           19                Brazil    São Paulo
# 21           20         United States    Las Vegas
# 22           21                 Qatar       Lusail
# 23           22  United Arab Emirates   Yas Marina
#
#                                     OfficialEventName  EventDate  \
# 0          FORMULA 1 2018 ROLEX AUSTRALIAN GRAND PRIX 2018-03-25
# 1          FORMULA 1 2018 GULF AIR BAHRAIN GRAND PRIX 2018-04-08
# 2          FORMULA 1 2018 HEINEKEN CHINESE GRAND PRIX 2018-04-15
# ...

# %% [markdown]
# # Events

# %%
events_df = (
    events_schedule_df[["year", "RoundNumber", "EventFormat", "Country", "Location"]]
    .reset_index(drop=True)
)
events_df["EventFormat"] = events_df["EventFormat"].apply(lambda x : False if x=="conventional" else True)
events_df
# Out:
#      year  RoundNumber  EventFormat               Country     Location
# 0    2018            1        False             Australia    Melbourne
# 1    2018            2        False               Bahrain       Sakhir
# 2    2018            3        False                 China     Shanghai
# 3    2018            4        False            Azerbaijan         Baku
# 4    2018            5        False                 Spain    Barcelona
# ..    ...          ...          ...                   ...          ...
# 200  2026           18        False                Mexico  Mexico City
# 201  2026           19        False                Brazil    São Paulo
# 202  2026           20        False         United States    Las Vegas
# 203  2026           21        False                 Qatar       Lusail
# 204  2026           22        False  United Arab Emirates   Yas Marina
#
# [205 rows x 5 columns]

# %%
circuits_df = pd.read_sql('SELECT id, country, location, circuit_name FROM tracks', engine)
circuits_df.head()
# Out:
#    id     country   location                    circuit_name
# 0   0   Australia  Melbourne  Albert Park Grand Prix Circuit
# 1   1         USA     Austin         Circuit of the Americas
# 2   2     Bahrain     Sakhir   Bahrain International Circuit
# 3   3  Azerbaijan       Baku               Baku City Circuit
# 4   4       Spain  Barcelona  Circuit de Barcelona-Catalunya

# %%
circuits_df["circuit_info"] = (circuits_df["country"] + " " + circuits_df["location"] + " " + circuits_df["circuit_name"]).str.lower()
circuits_df[["id", "circuit_info"]].head()
# Out:
#    id                                       circuit_info
# 0   0  australia melbourne albert park grand prix cir...
# 1   1                 usa austin circuit of the americas
# 2   2       bahrain sakhir bahrain international circuit
# 3   3                  azerbaijan baku baku city circuit
# 4   4     spain barcelona circuit de barcelona-catalunya

# %%
def to_circuit_id(row):

    location = row["Location"].lower()

    replace_dict = {
        "Montréal" : "Montreal", 
        "Yas Island" : "Yas", 
        "Miami Gardens" : "Miami",
    }
    for key in replace_dict:
        location = location.replace(key.lower(), replace_dict[key].lower())

    for i in range(len(circuits_df)):
        if location in circuits_df.loc[i, "circuit_info"]:
            return int(circuits_df.loc[i, "id"])
    return None

events_df["circuit_id"] = events_df.apply(to_circuit_id, axis=1)
events_df['circuit_id'] = events_df['circuit_id'].astype('Int32')
events_df
# Out:
#      year  RoundNumber  EventFormat               Country     Location  \
# 0    2018            1        False             Australia    Melbourne
# 1    2018            2        False               Bahrain       Sakhir
# 2    2018            3        False                 China     Shanghai
# 3    2018            4        False            Azerbaijan         Baku
# 4    2018            5        False                 Spain    Barcelona
# ..    ...          ...          ...                   ...          ...
# 200  2026           18        False                Mexico  Mexico City
# 201  2026           19        False                Brazil    São Paulo
# 202  2026           20        False         United States    Las Vegas
# 203  2026           21        False                 Qatar       Lusail
# 204  2026           22        False  United Arab Emirates   Yas Marina
#
#      circuit_id
# 0             0
# 1             2
# 2            14
# 3             3
# 4             4
# ...

# %%
events_df[pd.isna(events_df["circuit_id"])]
# Out:
# Empty DataFrame
# Columns: [year, RoundNumber, EventFormat, Country, Location, circuit_id]
# Index: []

# %%
events_df_clean = (
    events_df[events_df["RoundNumber"]>0][["circuit_id", "year", "RoundNumber", "EventFormat"]]
    .rename(columns={
        "RoundNumber" : "round",
        "EventFormat" : "is_sprint"
    })
)

events_df_clean
# Out:
#      circuit_id  year  round  is_sprint
# 0             0  2018      1      False
# 1             2  2018      2      False
# 2            14  2018      3      False
# 3             3  2018      4      False
# 4             4  2018      5      False
# ..          ...   ...    ...        ...
# 200          13  2026     18      False
# 201           7  2026     19      False
# 202          30  2026     20      False
# 203          27  2026     21      False
# 204          20  2026     22      False
#
# [195 rows x 4 columns]

# %%
events_df_clean.iloc[43]
# Out:
# circuit_id       11
# year           2020
# round             2
# is_sprint     False
# Name: 45, dtype: object

# %%
with engine.connect() as conn:
    conn.execute(text("DELETE FROM events"))
    conn.commit()

# %%
events_df_clean.rename({"circuit_id" : "track_id"})
# Out:
#      circuit_id  year  round  is_sprint
# 0             0  2018      1      False
# 1             2  2018      2      False
# 2            14  2018      3      False
# 3             3  2018      4      False
# 4             4  2018      5      False
# ..          ...   ...    ...        ...
# 200          13  2026     18      False
# 201           7  2026     19      False
# 202          30  2026     20      False
# 203          27  2026     21      False
# 204          20  2026     22      False
#
# [195 rows x 4 columns]

# %%
events_df_clean.to_sql("events", engine, if_exists="append", index=True, index_label="id")
# Out:
# 195

# %% [markdown]
# # Sessions

# %%
session_names = ["Unknown",
                 "Practice 1", 
                 "Practice 2", 
                 "Practice 3", 
                 "Qualifying", 
                 "Race", 
                 "Sprint Qualifying", 
                 "Sprint"]

session_types_df = pd.DataFrame(session_names, columns=["name"])
session_types_df
# Out:
#                 name
# 0            Unknown
# 1         Practice 1
# 2         Practice 2
# 3         Practice 3
# 4         Qualifying
# 5               Race
# 6  Sprint Qualifying
# 7             Sprint

# %%
session_types_df.to_sql("session_types", engine, if_exists='append', index=True, index_label="id")
# Out:
# 8

# %%
import fastf1

session_data = []
for i in range(len(events_schedule_df)):
    event = events_schedule_df.iloc[i]

    if event["EventFormat"] == 'testing':
        continue

    event_id = events_df_clean[(events_df_clean["year"] == event["year"]) &
                               (events_df_clean["round"] == event["RoundNumber"])].index
     
    if len(event_id) != 1:
        print(event_id)
        raise ValueError
    event_id = event_id[0]

    for session_num in range(1, 6):
        s_type = event[f"Session{session_num}"]
        
        if s_type in session_names:
            s_type_ind = session_names.index(s_type)
        else:
            s_type_ind = session_names.index("Unknown")
        s_datetime = event[f"Session{session_num}DateUtc"]

        session_data.append((event_id, s_type_ind, s_datetime))

# %%
sessions_df = pd.DataFrame(data=session_data, 
                        columns=["event_id", "session_type", "datetime_start_utc"])

sessions_df
# Out:
#      event_id  session_type  datetime_start_utc
# 0           0             1 2018-03-23 01:00:00
# 1           0             2 2018-03-23 05:00:00
# 2           0             3 2018-03-24 03:00:00
# 3           0             4 2018-03-24 06:00:00
# 4           0             5 2018-03-25 05:10:00
# ..        ...           ...                 ...
# 970       204             1 2026-12-04 09:30:00
# 971       204             2 2026-12-04 13:00:00
# 972       204             3 2026-12-05 10:30:00
# 973       204             4 2026-12-05 14:00:00
# 974       204             5 2026-12-06 13:00:00
#
# [975 rows x 3 columns]

# %%
sessions_df.to_sql("sessions", engine, if_exists='append', index=True, index_label="id")
# Out:
# 975

# %%
import pandas as pd

sessions = pd.read_sql(f"SELECT s.id, st.name, e.year, e.round, s.event_id FROM sessions s JOIN events e ON s.event_id = e.id JOIN session_types st ON s.session_type=st.id WHERE s.id>299", engine)
sessions
# Out:
#       id        name  year  round  event_id
# 0    300  Practice 1  2021      2        63
# 1    301  Practice 2  2021      2        63
# 2    302  Practice 3  2021      2        63
# 3    303  Qualifying  2021      2        63
# 4    304        Race  2021      2        63
# ..   ...         ...   ...    ...       ...
# 670  970  Practice 1  2026     22       204
# 671  971  Practice 2  2026     22       204
# 672  972  Practice 3  2026     22       204
# 673  973  Qualifying  2026     22       204
# 674  974        Race  2026     22       204
#
# [675 rows x 5 columns]

# %%
import time
import fastf1

fastf1.logger.set_log_level('ERROR')

i = 0
while i < len(sessions):
    session_id = sessions.loc[i, "id"]
    year = sessions.loc[i, "year"]
    round = sessions.loc[i, "round"]
    type = sessions.loc[i, "name"]

    i += 1

    if type in ("Race", "Sprint"):
        try:
            num_laps = None
            fastf1_session = fastf1.get_session(year, round, type)
            fastf1_session.load(laps=True)

            num_laps = fastf1_session.total_laps

            with engine.connect() as connection:
                connection.execute(text(f"UPDATE sessions SET total_laps={num_laps} WHERE id={session_id}"))
                connection.commit()
            print(f"Обновлено session_id={session_id}")

        except fastf1.exceptions.DataNotLoadedError as e:
            print(e)
        except fastf1.exceptions.RateLimitExceededError as e:
            i -= 1
            print("RateLimitExceededError")
            time.sleep(300)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 30
#      26             print(f"Обновлено session_id={session_id}")
#      27
#      28         except fastf1.exceptions.DataNotLoadedError as e:
#      29             print(e)
# ---> 30         except fastf1.exceptions.RateLimitExceededError as e:
#      31             i -= 1
#      32             print("RateLimitExceededError")
#      33             time.sleep(300)
#
# File ~/project/f1pace/.venv/lib/python3.12/site-packages/fastf1/core.py:1425, in Session.load(self, laps, telemetry, weather, messages, livedata)
#    1422     self._fix_missing_laps_retired_on_track()
#    1424 if telemetry:
# -> 1425     self._load_telemetry(livedata=livedata)
#    1427 if weather:
#    1428     self._load_weather_data(livedata=livedata)
#
# ...

# %%
import fastf1
fastf1.logger.set_log_level('INFO')
s = fastf1.get_session(2026, 1, 1)
s.load()
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Practice 1 [v3.8.2]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 14
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 14)
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# core        WARNING 	Car telemetry data is unavailable!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# ...
